# %% [markdown]
# ## New York Times Article Search
# ---
# #### To df

# %%
from pynytimes import NYTAPI
import pandas as pd
import datetime

# %%
nyt = NYTAPI("mwnXWF71cgmtnfQdbR5hSBDc1ivbObUX", parse_dates=True, https=False)

articles = nyt.article_search(
    query = "Election",
    results = 5,
    dates = {
        "2010": datetime.datetime(2022, 1, 1),
        "2022": datetime.datetime(2022, 12, 31)
    },
    options = {
        "sort": "oldest",
        "sources": [
            "New York Times",
            "AP",
            "Reuters",
            "International Herald Tribune"
        ],
        "news_desk": [
            "Politics"
        ],
        "type_of_material": [
            "News Analysis"
        ]
    }
)

print(articles)
# Out:
# [{'abstract': 'After $6 billion, two dozen presidential primary days, four general election debates and more TV ads than anyone could watch, the two parties essentially fought to a standstill.', 'web_url': 'https://www.nytimes.com/2012/11/08/us/politics/a-divided-nation-keeps-the-status-quo.html', 'snippet': 'After $6 billion, two dozen presidential primary days, four general election debates and more TV ads than anyone could watch, the two parties essentially fought to a standstill.', 'lead_paragraph': 'After $6 billion, two dozen presidential primary election days, a pair of national conventions, four general election debates, hundreds of Congressional contests and more television advertisements than anyone would ever want to watch, the two major political parties in America essentially fought to a standstill.', 'print_section': 'P', 'print_page': '3', 'source': 'The New York Times', 'multimedia': [{'rank': 0, 'subtype': 'xlarge', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2012/11/08/us/politics/08assess_span1/08assess_span1-articleLarge.jpg', 'height': 330, 'width': 600, 'legacy': {'xlarge': 'images/2012/11/08/us/politics/08assess_span1/08assess_span1-articleLarge.jpg', 'xlargewidth': 600, 'xlargeheight': 330}, 'subType': 'xlarge', 'crop_name': 'articleLarge'}, {'rank': 0, 'subtype': 'blog480', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2012/11/08/us/politics/08assess_span1/08assess_span1-blog480.jpg', 'height': 300, 'width': 480, 'legacy': {}, 'subType': 'blog480', 'crop_name': 'blog480'}, {'rank': 0, 'subtype': 'jumbo', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2012/11/08/us/politics/08assess_span1/08assess_span1-jumbo.jpg', 'height': 639, 'width': 1024, 'legacy': {}, 'subType': 'jumbo', 'crop_name': 'jumbo'}, {'rank': 0, 'subtype': 'popup', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2012/11/08/us/politics/08assess_span1/08assess_span1-popup.jpg', 'height': 406, 'width': 650, 'legacy': {}, 'subType': 'popup', 'crop_name': 'popup'}, {'rank': 0, 'subtype': 'superJumbo', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2012/11/08/us/politics/08assess_span1/08assess_span1-superJumbo.jpg', 'height': 1278, 'width': 2048, 'legacy': {}, 'subType': 'superJumbo', 'crop_name': 'superJumbo'}, {'rank': 0, 'subtype': 'articleInline', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2012/11/08/us/politics/08assess_span1/08assess_span1-articleInline.jpg', 'height': 119, 'width': 190, 'legacy': {}, 'subType': 'articleInline', 'crop_name': 'articleInline'}, {'rank': 0, 'subtype': 'sfSpan', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2012/11/08/us/politics/08assess_span1/08assess_span1-sfSpan.jpg', 'height': 246, 'width': 395, 'legacy': {}, 'subType': 'sfSpan', 'crop_name': 'sfSpan'}, {'rank': 0, 'subtype': 'hpLarge', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2012/11/08/us/politics/08assess_span1/08assess_span1-hpLarge.jpg', 'height': 300, 'width': 511, 'legacy': {}, 'subType': 'hpLarge', 'crop_name': 'hpLarge'}, {'rank': 0, 'subtype': 'thumbnail', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2012/11/08/us/politics/08assess_span1/08assess_span1-thumbStandard.jpg', 'height': 75, 'width': 75, 'legacy': {'thumbnail': 'images/2012/11/08/us/politics/08assess_span1/08assess_span1-thumbStandard.jpg', 'thumbnailwidth': 75, 'thumbnailheight': 75}, 'subType': 'thumbnail', 'crop_name': 'thumbStandard'}, {'rank': 0, 'subtype': 'thumbLarge', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2012/11/08/us/politics/08assess_span1/08assess_span1-thumbLarge.jpg', 'height': 150, 'width': 150, 'legacy': {}, 'subType': 'thumbLarge', 'crop_name': 'thumbLarge'}], 'headline': {'main': 'Obama Wins a Clear Victory, but Balance of Power Is Unchanged in Washington', 'kicker': 'News Analysis', 'content_kicker': None, 'print_headline': 'Smoke Clears to Show a Battlefield L ...

# %%
# for each of the articles in the list, get the information that is stored in a nested dictionary:
headline = map(lambda x: x["headline"]["main"], articles)
author = map(lambda x: x["headline"]["kicker"], articles)
leadparagraph = map(lambda x: x["lead_paragraph"], articles)
pubdate = map(lambda x: x["pub_date"], articles)
weburl = map(lambda x: x["web_url"],articles)

# since keywords are a branch down in the nested dictionary, we need to add an additional for loop to collect all keywords:
keywords = map(lambda x:list(i["value"] for i in x["keywords"]), articles)

# %%
data={'headline': list(headline), 'author': list(author), 'leadparagraph':list(leadparagraph),
     'publication date': list(pubdate), "keywords": list(keywords),"weburl":list(weburl)}
df = pd.DataFrame(data)
df
# Out:
#                                             headline         author  \
# 0  Obama Wins a Clear Victory, but Balance of Pow...  News Analysis
# 1  Senate Republicans Are Newly Hopeful About the...           None
# 2  For Red-State Democrats, Accusation Against Ka...  News Analysis
# 3  Kavanaugh Could Help G.O.P. in Senate Midterms...  News Analysis
# 4  How Trump-Fed Conspiracy Theories About Migran...  News Analysis
# 5  Inside the Republican Strategy to Discredit th...  News Analysis
# 6  Trump Behaves One Way on Race. Democrats Deman...  News Analysis
# 7  On Health Care, 2020 Democrats Find Their Firs...  News Analysis
# 8  Mueller Report Puts Pressure on 2020 Candidate...  News Analysis
# 9  Kamala Harris Makes the Case That Joe Biden Sh...  News Analysis
#
#                                        leadparagraph  \
# 0  After $6 billion, two dozen presidential prima...
# 1  WASHINGTON — After a turbulent first year conf...
# 2  WASHINGTON — The sexual assault accusation aga...
# 3  WASHINGTON — By agreeing to delay Judge Brett ...
# 4  MURPHYSBORO, Ill. — Alicia Hooten thinks the c...
# 5  TALLAHASSEE, Fla. — The concerted effort by Re...
# 6  WASHINGTON — The irony was difficult to miss: ...
# 7  The debate unfolded over a period of days, on ...
# 8  The conclusion by the special counsel that Pre...
# 9  This was the moment Joseph R. Biden Jr. had to...
#
#            publication date  \
# 0 2012-11-07 16:44:30+00:00
# 1 2018-06-02 09:00:06+00:00
# 2 2018-09-19 14:01:01+00:00
# 3 2018-09-29 14:32:32+00:00
# 4 2018-10-29 21:34:05+00:00
# 5 2018-11-13 01:34:32+00:00
# 6 2019-02-04 01:02:16+00:00
# 7 2019-02-20 10:00:08+00:00
# 8 2019-03-25 09:00:05+00:00
# 9 2019-06-28 03:55:14+00:00
#
#                                             keywords  \
# 0  [House of Representatives, Democratic Party, S...
# 1  [Republican Party, Midterm Elections (2018), E...
# 2  [Midterm Elections (2018), Kavanaugh, Brett M,...
# 3  [Midterm Elections (2018), Elections, House of...
# 4  [Midterm Elections (2018), Trump, Donald J, Im...
# 5  [Midterm Elections (2018), Florida, Elections,...
# 6  [Presidential Election of 2020, Democratic Par...
# 7  [Democratic Party, Presidential Election of 20...
# 8  [Presidential Election of 2016, Russian Interf...
# 9  [Presidential Election of 2020, Debates (Polit...
#
#                                               weburl
# 0  https://www.nytimes.com/2012/11/08/us/politics...
# 1  https://www.nytimes.com/2018/06/02/us/politics...
# 2  https://www.nytimes.com/2018/09/19/us/politics...
# 3  https://www.nytimes.com/2018/09/29/us/politics...
# 4  https://www.nytimes.com/2018/10/29/us/politics...
# 5  https://www.nytimes.com/2018/11/12/us/politics...
# 6  https://www.nytimes.com/2019/02/03/us/politics...
# 7  https://www.nytimes.com/2019/02/20/us/politics...
# 8  https://www.nytimes.com/2019/03/25/us/politics...
# 9  https://www.nytimes.com/2019/06/27/us/politics...

# %%
df.weburl[0]
# Out:
# 'https://www.nytimes.com/2012/11/08/us/politics/a-divided-nation-keeps-the-status-quo.html'

# %% [markdown]
# ## All Article Search from min year
# ---
# #### Can only access Paragraph

# %%
from datetime import date
import requests
import time 
import sys

KEY = "mwnXWF71cgmtnfQdbR5hSBDc1ivbObUX"

# earliest year supported by NYT API
NYT_MIN_YEAR = 2010

# now 
YEAR = (date.today()).year 

# But to keep things rational, maybe just do 100 years
MIN_YEAR = NYT_MIN_YEAR

# Given a term, I return the total in a year
def countForTerm(term,year):
	# Note, we filter to one key cuz we only really care about the count
	api = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?&api-key={KEY}&fl=web_url"
	# pass term here, requests will url encode
	response = requests.get(api, params=[("fq",f"pub_year:{year} AND headline:{term}")], verify=False)
	data = response.json()

	if "fault" in data:
		print("ERROR:",data["fault"]["faultstring"])
		sys.exit()

	total = data["response"]["meta"]["hits"]

	return total

def main(term):
	# it's an array, but reduce to a string
	term = " ".join(term)
	print(f"Searching for {term} from {MIN_YEAR} to {YEAR}")
	for year in range(MIN_YEAR, YEAR):
		total = countForTerm(term, year)
		print(year,total)
		time.sleep(6)

main('election usa')
# Out:
# Searching for e l e c t i o n   u s a from 2010 to 2022
# c:\Users\DELSTEI9\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.nytimes.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 2010 261
# c:\Users\DELSTEI9\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.nytimes.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 2011 257
# c:\Users\DELSTEI9\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.nytimes.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 2012 242
# c:\Users\DELSTEI9\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.nytimes.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 2013 186
# c:\Users\DELSTEI9\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.nytimes.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 2014 184
# c:\Users\DELSTEI9\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.nytimes.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 2015 119
# c:\Users\DELSTEI9\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.nytimes.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 2016 74
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\DELSTEI9\OneDrive - EY\Documents\GitHub\NLP\nytapi_dataframe.ipynb Cell 8 in <cell line: 42>()
#      <a href='vscode-notebook-cell:/c%3A/Users/DELSTEI9/OneDrive%20-%20EY/Documents/GitHub/NLP/nytapi_dataframe.ipynb#W6sZmlsZQ%3D%3D?line=38'>39</a> 		print(year,total)
#      <a href='vscode-notebook-cell:/c%3A/Users/DELSTEI9/OneDrive%20-%20EY/Documents/GitHub/NLP/nytapi_dataframe.ipynb#W6sZmlsZQ%3D%3D?line=39'>40</a> 		time.sleep(6)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/DELSTEI9/OneDrive%20-%20EY/Documents/GitHub/NLP/nytapi_dataframe.ipynb#W6sZmlsZQ%3D%3D?line=41'>42</a> main('election usa')
#
# c:\Users\DELSTEI9\OneDrive - EY\Documents\GitHub\NLP\nytapi_dataframe.ipynb Cell 8 in main(term)
#      <a href='vscode-notebook-cell:/c%3A/Users/DELSTEI9/OneDrive%20-%20EY/Documents/GitHub/NLP/nytapi_dataframe.ipynb#W6sZmlsZQ%3D%3D?line=37'>38</a> total = countForTerm(term, year)
#      <a href='vscode-notebook-cell:/c%3A/Users/DELSTEI9/OneDrive%20-%20EY/Documents/GitHub/NLP/nytapi_dataframe.ipynb#W6sZmlsZQ%3D%3D?line=38'>39</a> print(year,total)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/DELSTEI9/OneDrive%20-%20EY/Documents/GitHub/NLP/nytapi_dataframe.ipynb#W6sZmlsZQ%3D%3D?line=39'>40</a> time.sleep(6)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Article Search different approach
# ---
# #### to .csv

# %%
import requests as req
import time
API_KEY='mwnXWF71cgmtnfQdbR5hSBDc1ivbObUX' # your API key
TOPIC='Election' # keyword

# %%
for i in range(10):
  url='https://api.nytimes.com/svc/search/v2/articlesearch.json?q='+TOPIC+'&api-key='+API_KEY+'&page='+str(i)
  response = req.get(url, verify=False).json()
  time.sleep(6)
response

# %%
# Extract the necessary fields from the response.
articles = []
docs = response['response']['docs']
print(response[0])
for doc in docs:
        filteredDoc = {}
        filteredDoc['title'] = doc['headline']['main']
        filteredDoc['abstract'] = doc['abstract']
        filteredDoc['paragraph']=doc['lead_paragraph']
        articles.append(filteredDoc)
articles[:10]

# %%
import pandas as pd
df = pd.DataFrame(data=articles)
df.to_csv('TechArticles.csv')
